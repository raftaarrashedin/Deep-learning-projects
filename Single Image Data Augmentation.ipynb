# %%
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing import image
import keras.utils as image
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
img = image.load_img('/content/cat.42.jpg', target_size = (200,200))

# %%
plt.imshow(img)

# %%
print(type(img))
# Out:
# <class 'PIL.Image.Image'>

# %%
datagen = ImageDataGenerator(
    rotation_range = 30,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True,
    width_shift_range = 0.2,
    height_shift_range = 0.2
 )

# %%
img = image.img_to_array(img)

# %%
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
print(img.shape)
# Out:
# (200, 200, 3)

# %%
input_batch = img.reshape(1,200,200,3)

# %%
i = 0

for output in datagen.flow(input_batch, batch_size = 1, save_to_dir = '/content/sample_data') :

  i = i + 1

  if i == 10 :
    break

# %%
img1 = image.load_img('/content/sample_data/_0_1126.png')

# %%
img1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>

# %%
img2 = image.load_img('/content/sample_data/_0_2046.png')

# %%
img2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>

# %%
img3 = image.load_img('/content/sample_data/_0_5499.png')

# %%
img3
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>
