# %%
import numpy as np
docs = [
    'The Mathematical Foundation of Data Science!',
    'Mathematics in Data Science:',
    'Foundation and Language: Mathematics serves as the foundational language and toolkit of data science.',
    'Extracting Insights: Data scientists use mathematical concepts to extract valuable insights from large datasets',
    'Statistics:',
    'Data Understanding: Statistics helps make sense of data variations identify trends and draw meaningful conclusions.',
    'Linear Algebra:',
    'Multi-dimensional Data: Facilitates data manipulation in multiple dimensions important for tasks like dimensionality reduction and machine learning.',
    'Calculus:',
    'Optimization: Underpins optimization algorithms aiding in model fine tuning.',
    'Probability Theory:',
    'Probabilistic Models: Informs the creation of probabilistic models vital for risk assessment and uncertainty quantification.',
    'Mathematical Rigor:',
    'Reliability: Ensures the reliability of data analysis fostering confidence in decision making.',
    'Empowering Data Science:',
    'Transforming Data: Math empowers data scientists to transform raw information into actionable knowledge making it an indispensable tool in their arsenal.'
]

# %%
from keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts(docs)

# %%
len(tokenizer.word_index)
# Out:
# 95

# %%
sequences = tokenizer.texts_to_sequences(docs)
sequences
# Out:
# [[5, 7, 8, 2, 1, 6],
#  [9, 3, 1, 6],
#  [8, 4, 10, 9, 21, 22, 5, 23, 10, 4, 24, 2, 1, 6],
#  [25, 11, 1, 12, 26, 7, 27, 13, 28, 29, 11, 30, 31, 32],
#  [14],
#  [1, 33, 14, 34, 35, 36, 2, 1, 37, 38, 39, 4, 40, 41, 42],
#  [43, 44],
#  [45, 46, 1, 47, 1, 48, 3, 49, 50, 51, 15, 52, 53, 54, 55, 4, 56, 57],
#  [58],
#  [16, 59, 16, 60, 61, 3, 62, 63, 64],
#  [65, 66],
#  [17, 18, 67, 5, 68, 2, 17, 18, 69, 15, 70, 71, 4, 72, 73],
#  [7, 74],
#  [19, 75, 5, 19, 2, 1, 76, 77, 78, 3, 79, 20],
#  [80, 1, 6],
#  [81,
#   1,
#   82,
#   83,
#   1,
#   12,
#   13,
#   84,
#   85,
#   86,
#   87,
#   88,
#   89,
#   20,
#   90,
#   91,
#   92,
#   93,
#   3,
#   94,
#   95]]

# %%
from keras.utils import pad_sequences
sequences = pad_sequences(sequences, padding = 'post')
sequences
sequences[0].shape
# Out:
# (21,)

# %%
from keras.layers import Dense, SimpleRNN, Embedding, Flatten
from keras import Sequential

# %%
model = Sequential()

model.add(Embedding(10000,2))
model.add(SimpleRNN(32, return_sequences = False))
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_2 (Embedding)     (None, None, 2)           20000
#
#  simple_rnn (SimpleRNN)      (None, 32)                1120
#
#  dense (Dense)               (None, 1)                 33
#
# ...
# Total params: 21153 (82.63 KB)
# Trainable params: 21153 (82.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam',loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# pred = model.predict(sequences)
# print(pred)

# %%
history = model.fit(X_train, y_train, epochs = 5, validation_data = (X_test, y_test))
