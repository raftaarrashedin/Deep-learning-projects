# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/df_Clean.csv')
df.head()
# Out:
#    Unnamed: 0      Region       State   Area        City Consumer_profile  \
# 0           0       South   Karnataka  Urban   Bangalore         Business
# 1           1       South   Karnataka  Rural   Bangalore         Business
# 2           2       North     Haryana  Urban  Chandigarh         Personal
# 3           3       South  Tamil Nadu  Urban     Chennai         Business
# 4           4  North East   Jharkhand  Rural      Ranchi         Personal
#
#   Product_category Product_type  AC_1001_Issue  AC_1002_Issue  ...  \
# 0    Entertainment           TV              0              0  ...
# 1        Household           AC              1              1  ...
# 2        Household           AC              0              1  ...
# 3    Entertainment           TV              0              0  ...
# 4    Entertainment           TV              0              0  ...
#
#    TV_2001_Issue  TV_2002_Issue  TV_2003_Issue  Claim_Value  Service_Centre  \
# ...

# %%
df.shape
# Out:
# (358, 21)

# %%
df.drop(['Unnamed: 0'], axis = 1, inplace= True)

# %%
df.isnull().sum()
# Out:
# Region              0
# State               0
# Area                0
# City                0
# Consumer_profile    0
# Product_category    0
# Product_type        0
# AC_1001_Issue       0
# AC_1002_Issue       0
# AC_1003_Issue       0
# TV_2001_Issue       0
# TV_2002_Issue       0
# TV_2003_Issue       0
# Claim_Value         0
# Service_Centre      0
# Product_Age         0
# Purchased_from      0
# Call_details        0
# Purpose             0
# Fraud               0
# dtype: int64

# %%
df.dtypes
# Out:
# Region               object
# State                object
# Area                 object
# City                 object
# Consumer_profile     object
# Product_category     object
# Product_type         object
# AC_1001_Issue         int64
# AC_1002_Issue         int64
# AC_1003_Issue         int64
# TV_2001_Issue         int64
# TV_2002_Issue         int64
# TV_2003_Issue         int64
# Claim_Value         float64
# Service_Centre        int64
# Product_Age           int64
# Purchased_from       object
# Call_details        float64
# Purpose              object
# Fraud                 int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Region', 'State', 'Area', 'City', 'Consumer_profile',
#        'Product_category', 'Product_type', 'AC_1001_Issue', 'AC_1002_Issue',
#        'AC_1003_Issue', 'TV_2001_Issue', 'TV_2002_Issue', 'TV_2003_Issue',
#        'Claim_Value', 'Service_Centre', 'Product_Age', 'Purchased_from',
#        'Call_details', 'Purpose', 'Fraud'],
#       dtype='object')

# %%
# fraud_by_region = df.groupby('Region')['Fraud'].sum().reset_index()

# # Set Seaborn style
# sns.set(style="whitegrid")

# # Create a bar chart using Seaborn with conditional coloring
# plt.figure(figsize=(10, 6))
# sns.barplot(x='Region', y='Fraud', data=fraud_by_region, palette=['green' if fraud == 0 else 'red' for fraud in fraud_by_region['Fraud']])
# plt.xlabel('Region')
# plt.ylabel('Number of Fraud Claims')
# plt.title('Fraud Claims by Region')

# plt.xticks(rotation=45)
# plt.tight_layout()
# # plt.show()
# sns.relplot(data=df, x="Region", y="Fraud", hue="smoker")
sns.relplot(data=df, x="Region", y="Fraud")
